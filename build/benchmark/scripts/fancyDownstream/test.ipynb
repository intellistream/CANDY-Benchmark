# %%
from warthunderSave import *

# %%
countries = [
        'USA',
        'Germany',
        'USSR',
        'Britain',
        'Japan',
        'China',
        'Italy',
        'France',
        'France',
        'Sweden',
        'Israel'
    ]
types= [
        'aircraft',
        'ground_vehicles'
    ]
categories = []
for i in countries:
    for j in types:
        str=i+'_'+j
        #print(i,j)
        categories.append(str)
print(categories)
# Out:
# ['USA_aircraft', 'USA_ground_vehicles', 'Germany_aircraft', 'Germany_ground_vehicles', 'USSR_aircraft', 'USSR_ground_vehicles', 'Britain_aircraft', 'Britain_ground_vehicles', 'Japan_aircraft', 'Japan_ground_vehicles', 'China_aircraft', 'China_ground_vehicles', 'Italy_aircraft', 'Italy_ground_vehicles', 'France_aircraft', 'France_ground_vehicles', 'France_aircraft', 'France_ground_vehicles', 'Sweden_aircraft', 'Sweden_ground_vehicles', 'Israel_aircraft', 'Israel_ground_vehicles']

# %%
getDescriptionCtx(1,categories[4])
# Out:
# /I-16_type_5
# /MiG-3-15
# /I-16_type_10
# /I-16_type_18
# /I-16_type_24
# /I-15_WR
# /I-15_M-22
# /I-15_M-25
# /I-15bis
# /I-153_M-62
# /Po-2
# /BB-1
# /Su-2_MV-5
# /Su-2_TSS-1
# /Su-2_(M-82)
# /Pe-3_(e)
# /Pe-3
# /Yak-2_KABB
# /SB_2M-100
# /SB_2M-103
# /Yak-4
# /Ar-2
# /SB_2M-103U_MV-3
# /SB_2M-105
# /SB_2M-103U
# /SB_2M-103_MV-3
# /Krasnolutsky%27s_I-15bis
# /Zhukovsky%27s_I-153-M62
# /PBY-5A_Catalina_(USSR)
# /Hampden_TB_Mk_I_(USSR)
# /MBR-2-M-34
# /Po-2M
# /TB-3M-17-32
# /Tandem_MAI
# /Yak-1
# /Yak-1B
# /Yak-7B
# /Yak-9
# /Yak-9B
# /MiG-3-15_(BK)
# /MiG-3-34
# /I-16_type_27
# /LaGG-3-8
# /LaGG-3-11
# /LaGG-3-35
# /LaGG-3-66
# /La-5
# /La-5F
# /IL-2_(1941)
# /IL-2_(1942)
# /IL-2-37
# /Pe-3bis
# /DB-3B
# /IL-4
# /Pe-2-1
# /Pe-2-31
# /Pe-2-83
# /LaGG-3-4
# /P-40E-1_(USSR)
# /Hurricane_Mk_IIB_(USSR)
# /I-153P
# /I-16_type_28
# /P-39K-1_(USSR)
# /LaGG-3-23
# /I-29
# /IL-2_M-82
# /LaGG-3-34
# /I-180S
# /I-301
# /Yak-9T
# /Yak-9K
# /Yak-3
# /Yak-9U
# /I-185_(M-82)
# /I-185_(M-71)
# ...
